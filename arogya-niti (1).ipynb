# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r'test.csv')

# %%
df.head(14)
# Out:
#     case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0    318439             21                  c                   3
# 1    318440             29                  a                   4
# 2    318441             26                  b                   2
# 3    318442              6                  a                   6
# 4    318443             28                  b                  11
# 5    318444             23                  a                   6
# 6    318445             26                  b                   2
# 7    318446             25                  e                   1
# 8    318447             23                  a                   6
# 9    318448             23                  a                   6
# 10   318449             10                  e                   1
# 11   318450              4                  a                   4
# 12   318451             16                  c                   3
# 13   318452             28                  b                  11
#
#    Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                     Z                                  3  gynecology
# 1                     X                                  2  gynecology
# 2                     Y                                  3  gynecology
# 3                     X                                  3  gynecology
# 4                     X                                  2  gynecology
# 5                     X                                  3  gynecology
# 6                     Y                                  2  gynecology
# 7                     X                                  4  gynecology
# 8                     X                                  4  gynecology
# 9                     X                                  3  gynecology
# 10                    X                                  4  gynecology
# 11                    X                                  3  gynecology
# 12                    Z                                  4  gynecology
# 13                    X                                  3  gynecology
#
#    Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0          S                  A        2.0      17006                2.0
# 1          S                  F        2.0      17006                2.0
# 2          Q                  D        4.0      17006                2.0
# 3          Q                  F        2.0      17006                2.0
# 4          R                  F        2.0      17006                2.0
# 5          Q                  F        2.0      17006                2.0
# 6          Q                  D        2.0      17006                2.0
# 7          S                  E        3.0      95946                NaN
# 8          Q                  F        3.0      95946                NaN
# 9          Q                  F        4.0      95946                NaN
# 10         Q                  E        2.0      95946                NaN
# 11         R                  F        3.0      95946                NaN
# 12         R                  A        3.0      95946                NaN
# 13         R                  F        4.0      95946                NaN
#
#    Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0          Emergency            Moderate                      2  71-80
# 1             Trauma            Moderate                      4  71-80
# 2          Emergency            Moderate                      3  71-80
# 3             Trauma            Moderate                      3  71-80
# 4             Trauma            Moderate                      4  71-80
# 5             Trauma            Moderate                      2  71-80
# 6             Trauma            Moderate                      2  71-80
# 7          Emergency            Moderate                      2  31-40
# 8             Trauma            Moderate                      2  31-40
# 9             Urgent            Moderate                      2  31-40
# 10            Trauma            Moderate                      2  31-40
# 11         Emergency            Moderate                      6  31-40
# 12            Trauma            Moderate                      3  31-40
# 13            Urgent            Moderate                      2  31-40
#
#     Admission_Deposit
# 0              3095.0
# 1              4018.0
# 2              4492.0
# 3              4173.0
# 4              4161.0
# 5              4659.0
# 6              4167.0
# 7              4396.0
# 8              4088.0
# 9              3925.0
# 10             4241.0
# 11             3468.0
# 12             4322.0
# 13             4315.0

# %%
df1=df[df['Hospital_code']==26]

# %%
df1.shape
# Out:
# (14447, 17)

# %%
df1.head()
# Out:
#     case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 2    318441             26                  b                   2
# 6    318445             26                  b                   2
# 15   318454             26                  b                   2
# 17   318456             26                  b                   2
# 21   318460             26                  b                   2
#
#    Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 2                     Y                                  3  gynecology
# 6                     Y                                  2  gynecology
# 15                    Y                                  5  gynecology
# 17                    Y                                  3  gynecology
# 21                    Y                                  2  gynecology
#
#    Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 2          Q                  D        4.0      17006                2.0
# 6          Q                  D        2.0      17006                2.0
# 15         S                  D        4.0      40728                8.0
# 17         P                  D        4.0      40728                8.0
# 21         R                  D        3.0      40728                8.0
#
#    Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 2          Emergency            Moderate                      3  71-80
# 6             Trauma            Moderate                      2  71-80
# 15         Emergency            Moderate                      4  51-60
# 17            Trauma            Moderate                      6  51-60
# 21            Urgent            Moderate                      6  51-60
#
#     Admission_Deposit
# 2              4492.0
# 6              4167.0
# 15             6818.0
# 17             4782.0
# 21             3410.0

# %%
df1['Ward_Type'].nunique()
# Out:
# 4

# %%
df1['Hospital_type_code'].nunique()
# Out:
# 1

# %%
df1['City_Code_Hospital'].nunique()
# Out:
# 1

# %%
df1['Hospital_region_code'].nunique()
# Out:
# 1

# %%
df1['Ward_Type'].value_counts()
# Out:
# R    5784
# Q    4875
# S    3123
# P     665
# Name: Ward_Type, dtype: int64

# %%
df1['Ward_Facility_Code'].nunique()
# Out:
# 1

# %%
df1['Bed Grade'].value_counts()
# Out:
# 2.0    5875
# 3.0    4837
# 4.0    2580
# 1.0    1155
# Name: Bed Grade, dtype: int64

# %%
df1['Type of Admission'].value_counts()
# Out:
# Trauma       7303
# Emergency    4673
# Urgent       2471
# Name: Type of Admission, dtype: int64

# %%
df1['Severity of Illness'].value_counts()
# Out:
# Moderate    8158
# Minor       3374
# Extreme     2915
# Name: Severity of Illness, dtype: int64

# %%
df1['Age'].value_counts()
# Out:
# 41-50     2979
# 31-40     2871
# 51-60     2186
# 21-30     2002
# 71-80     1461
# 61-70     1460
# 11-20      785
# 81-90      332
# 0-10       294
# 91-100      77
# Name: Age, dtype: int64

# %%
df1.head()
# Out:
#     case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 2    318441             26                  b                   2
# 6    318445             26                  b                   2
# 15   318454             26                  b                   2
# 17   318456             26                  b                   2
# 21   318460             26                  b                   2
#
#    Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 2                     Y                                  3  gynecology
# 6                     Y                                  2  gynecology
# 15                    Y                                  5  gynecology
# 17                    Y                                  3  gynecology
# 21                    Y                                  2  gynecology
#
#    Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 2          Q                  D        4.0      17006                2.0
# 6          Q                  D        2.0      17006                2.0
# 15         S                  D        4.0      40728                8.0
# 17         P                  D        4.0      40728                8.0
# 21         R                  D        3.0      40728                8.0
#
#    Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 2          Emergency            Moderate                      3  71-80
# 6             Trauma            Moderate                      2  71-80
# 15         Emergency            Moderate                      4  51-60
# 17            Trauma            Moderate                      6  51-60
# 21            Urgent            Moderate                      6  51-60
#
#     Admission_Deposit
# 2              4492.0
# 6              4167.0
# 15             6818.0
# 17             4782.0
# 21             3410.0

# %%
df1['patientid'].value_counts()
# Out:
# 114456    15
# 53073     11
# 57774     10
# 23711      9
# 85812      9
# 75079      9
# 34297      8
# 95965      8
# 105655     8
# 88709      7
# 44459      6
# 10116      6
# 73457      6
# 81795      6
# 37144      6
# 17040      6
# 28282      6
# 24123      6
# 89273      6
# 30438      6
# 52114      6
# 57898      6
# 120273     6
# 130341     6
# 123295     5
# 86726      5
# 49709      5
# 24144      5
# 57816      5
# 11510      5
#           ..
# 118863     1
# 64706      1
# 12411      1
# 15973      1
# 59464      1
# 102471     1
# 25374      1
# 30786      1
# 71742      1
# 47162      1
# 127075     1
# 131173     1
# 71782      1
# 36967      1
# 79994      1
# 8313       1
# 20599      1
# 88182      1
# 32885      1
# 34932      1
# 85422      1
# 112407     1
# 9267       1
# 93077      1
# 86127      1
# 98413      1
# 34924      1
# 127083     1
# 113451     1
# 2049       1
# Name: patientid, Length: 11332, dtype: int64

# %%
df1=df1.drop(['Hospital_code', 'Hospital_type_code','City_Code_Hospital','Hospital_region_code','Visitors with Patient'], axis = 1)

# %%
df1.head()
# Out:
#     case_id  Available Extra Rooms in Hospital  Department Ward_Type  \
# 2    318441                                  3  gynecology         Q
# 6    318445                                  2  gynecology         Q
# 15   318454                                  5  gynecology         S
# 17   318456                                  3  gynecology         P
# 21   318460                                  2  gynecology         R
#
#    Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 2                   D        4.0      17006                2.0
# 6                   D        2.0      17006                2.0
# 15                  D        4.0      40728                8.0
# 17                  D        4.0      40728                8.0
# 21                  D        3.0      40728                8.0
#
#    Type of Admission Severity of Illness    Age  Admission_Deposit
# 2          Emergency            Moderate  71-80             4492.0
# 6             Trauma            Moderate  71-80             4167.0
# 15         Emergency            Moderate  51-60             6818.0
# 17            Trauma            Moderate  51-60             4782.0
# 21            Urgent            Moderate  51-60             3410.0

# %%
df1=df1.drop(['Ward_Facility_Code'], axis = 1)

# %%
df1.head()
# Out:
#     case_id  Available Extra Rooms in Hospital  Department Ward_Type  \
# 2    318441                                  3  gynecology         Q
# 6    318445                                  2  gynecology         Q
# 15   318454                                  5  gynecology         S
# 17   318456                                  3  gynecology         P
# 21   318460                                  2  gynecology         R
#
#     Bed Grade  patientid  City_Code_Patient Type of Admission  \
# 2         4.0      17006                2.0         Emergency
# 6         2.0      17006                2.0            Trauma
# 15        4.0      40728                8.0         Emergency
# 17        4.0      40728                8.0            Trauma
# 21        3.0      40728                8.0            Urgent
#
#    Severity of Illness    Age  Admission_Deposit
# 2             Moderate  71-80             4492.0
# 6             Moderate  71-80             4167.0
# 15            Moderate  51-60             6818.0
# 17            Moderate  51-60             4782.0
# 21            Moderate  51-60             3410.0

# %%
df1['Stay'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Stay'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-5bd326fa6991> in <module>
# ----> 1 df1['Stay'].value_counts()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Stay'

# %%
df1.groupby(df1[df1['Available Extra Rooms in Hospital']>=4]['Available Extra Rooms in Hospital'])['Department'].value_counts()
# Out:
# Available Extra Rooms in Hospital  Department
# 4.0                                gynecology            3408
#                                    radiotherapy           318
#                                    anesthesia             308
#                                    TB & Chest disease     137
#                                    surgery                 10
# 5.0                                gynecology             735
#                                    radiotherapy            75
#                                    anesthesia              64
#                                    TB & Chest disease      30
#                                    surgery                  4
# 6.0                                gynecology             372
#                                    radiotherapy            42
#                                    anesthesia              30
#                                    TB & Chest disease      24
#                                    surgery                  3
# 7.0                                gynecology             163
#                                    radiotherapy            24
#                                    anesthesia              14
#                                    TB & Chest disease       3
# 8.0                                gynecology              82
#                                    radiotherapy             8
#                                    TB & Chest disease       7
#                                    anesthesia               5
# 9.0                                gynecology              20
#                                    TB & Chest disease       3
#                                    radiotherapy             1
# 10.0                               gynecology               8
#                                    TB & Chest disease       1
# 11.0                               gynecology               2
# 12.0                               gynecology               1
#                                    radiotherapy             1
# 21.0                               radiotherapy             1
# Name: Department, dtype: int64

# %%
df1.groupby(df1[df1['Stay']=='More than 100 Days']['Ward_Type'])['Department'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Stay'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-9b29f4079151> in <module>
# ----> 1 df1.groupby(df1[df1['Stay']=='More than 100 Days']['Ward_Type'])['Department'].value_counts()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Stay'

# %%
df1.groupby('Ward_Type')['Department'].value_counts()
# Out:
# Ward_Type  Department
# P          gynecology             530
#            radiotherapy            55
#            anesthesia              46
#            TB & Chest disease      32
#            surgery                  2
# Q          gynecology            3811
#            radiotherapy           443
#            anesthesia             423
#            TB & Chest disease     180
#            surgery                 18
# R          gynecology            4292
#            anesthesia             650
#            radiotherapy           624
#            TB & Chest disease     203
#            surgery                 15
# S          gynecology            2145
#            anesthesia             450
#            radiotherapy           363
#            TB & Chest disease     154
#            surgery                 11
# Name: Department, dtype: int64

# %%
df.groupby('Ward_Facility_Code')['Department'].value_counts()
# Out:
# Ward_Facility_Code  Department
# A                   gynecology             9810
#                     radiotherapy           1093
#                     anesthesia             1090
#                     TB & Chest disease      333
#                     surgery                  28
# B                   gynecology            12024
#                     radiotherapy           1321
#                     anesthesia             1075
#                     TB & Chest disease      512
#                     surgery                  28
# C                   gynecology            12395
#                     radiotherapy           1809
#                     anesthesia              313
#                     TB & Chest disease      196
#                     surgery                 103
# D                   gynecology            16895
#                     anesthesia             2398
#                     radiotherapy           2209
#                     TB & Chest disease      936
#                     surgery                  65
# E                   gynecology            18604
#                     anesthesia             2633
#                     radiotherapy           1781
#                     TB & Chest disease      613
#                     surgery                  76
# F                   gynecology            37474
#                     anesthesia             5200
#                     radiotherapy           4304
#                     TB & Chest disease     1575
#                     surgery                 164
# Name: Department, dtype: int64

# %%
df.groupby('Ward_Type')['Department'].value_counts()
# Out:
# Ward_Type  Department
# P          gynecology             1693
#            radiotherapy            199
#            anesthesia              160
#            TB & Chest disease       92
#            surgery                   9
# Q          gynecology            36632
#            radiotherapy           3906
#            anesthesia             3863
#            TB & Chest disease     1306
#            surgery                 174
# R          gynecology            42903
#            anesthesia             5485
#            radiotherapy           4826
#            TB & Chest disease     1615
#            surgery                 163
# S          gynecology            25453
#            radiotherapy           3516
#            anesthesia             3146
#            TB & Chest disease     1139
#            surgery                 118
# T          gynecology              518
#            radiotherapy             70
#            anesthesia               55
#            TB & Chest disease       13
# U          gynecology                3
# Name: Department, dtype: int64

# %%
df.groupby('Bed Grade')['Department'].value_counts()
# Out:
# Bed Grade  Department
# 1.0        gynecology             9474
#            radiotherapy           1181
#            TB & Chest disease      217
#            anesthesia              129
#            surgery                  61
# 2.0        gynecology            43341
#            radiotherapy           4864
#            anesthesia             2896
#            TB & Chest disease     1468
#            surgery                 211
# 3.0        gynecology            36282
#            anesthesia             6184
#            radiotherapy           4190
#            TB & Chest disease     1583
#            surgery                 120
# 4.0        gynecology            18074
#            anesthesia             3500
#            radiotherapy           2279
#            TB & Chest disease      896
#            surgery                  72
# Name: Department, dtype: int64

# %%
(df1.corr())
# Out:
#                                     case_id  \
# case_id                            1.000000
# Available Extra Rooms in Hospital  0.033870
# Bed Grade                          0.004001
# patientid                          0.006080
# City_Code_Patient                  0.087222
# Admission_Deposit                 -0.057181
#
#                                    Available Extra Rooms in Hospital  \
# case_id                                                     0.033870
# Available Extra Rooms in Hospital                           1.000000
# Bed Grade                                                  -0.101374
# patientid                                                   0.001870
# City_Code_Patient                                          -0.019743
# Admission_Deposit                                          -0.146230
#
#                                    Bed Grade  patientid  City_Code_Patient  \
# case_id                             0.004001   0.006080           0.087222
# Available Extra Rooms in Hospital  -0.101374   0.001870          -0.019743
# Bed Grade                           1.000000   0.001434           0.017571
# patientid                           0.001434   1.000000          -0.006427
# City_Code_Patient                   0.017571  -0.006427           1.000000
# Admission_Deposit                   0.031901  -0.004937           0.003673
#
#                                    Admission_Deposit
# case_id                                    -0.057181
# Available Extra Rooms in Hospital          -0.146230
# Bed Grade                                   0.031901
# patientid                                  -0.004937
# City_Code_Patient                           0.003673
# Admission_Deposit                           1.000000

# %%
df1.isna().sum()
# Out:
# case_id                                0
# Available Extra Rooms in Hospital      0
# Department                             0
# Ward_Type                              0
# Bed Grade                              0
# patientid                              0
# City_Code_Patient                    203
# Type of Admission                      0
# Severity of Illness                    0
# Age                                    0
# Admission_Deposit                      0
# dtype: int64

# %%
df1[df1['City_Code_Patient'].isnull()]
# Out:
#         case_id  Available Extra Rooms in Hospital          Department  \
# 888      319327                                  2          anesthesia
# 3709     322148                                  2          anesthesia
# 8075     326514                                  2        radiotherapy
# 8336     326775                                  2          gynecology
# 8807     327246                                  2        radiotherapy
# 9373     327812                                  2          gynecology
# 10420    328859                                  4          gynecology
# 10421    328860                                  3          gynecology
# 11705    330144                                  3          gynecology
# 13886    332325                                  2          anesthesia
# 13888    332327                                  6          gynecology
# 13969    332408                                  2  TB & Chest disease
# 14515    332954                                  4          gynecology
# 14517    332956                                  3          gynecology
# 14756    333195                                  2        radiotherapy
# 14757    333196                                  2  TB & Chest disease
# 14758    333197                                  2        radiotherapy
# 14983    333422                                  3        radiotherapy
# 15175    333614                                  2          gynecology
# 16709    335148                                  4          anesthesia
# 16710    335149                                  2          gynecology
# 16712    335151                                  2  TB & Chest disease
# 16838    335277                                  6             surgery
# 17353    335792                                  4          gynecology
# 17354    335793                                  4          anesthesia
# 17991    336430                                  3          gynecology
# 17995    336434                                  3          gynecology
# 19566    338005                                  5          gynecology
# 21539    339978                                  5        radiotherapy
# 21544    339983                                  3        radiotherapy
# ...         ...                                ...                 ...
# 118161   436600                                  3          gynecology
# 118163   436602                                  6          anesthesia
# 118166   436605                                  2          gynecology
# 118630   437069                                  1          gynecology
# 120477   438916                                  3          gynecology
# 120741   439180                                  2          gynecology
# 121567   440006                                  4          anesthesia
# 121574   440013                                  2          anesthesia
# 121575   440014                                  4          anesthesia
# 121770   440209                                  2          gynecology
# 121855   440294                                  7          gynecology
# 123553   441992                                  4          gynecology
# 123575   442014                                  4          gynecology
# 123814   442253                                  4          gynecology
# 123825   442264                                  3          gynecology
# 123835   442274                                  3          gynecology
# 124709   443148                                  4          gynecology
# 125127   443566                                  3          gynecology
# 125427   443866                                  4          gynecology
# 127266   445705                                  3          gynecology
# 128370   446809                                  2          anesthesia
# 128710   447149                                  2          gynecology
# 128711   447150                                  3          gynecology
# 128734   447173                                  2          gynecology
# 130684   449123                                  4          gynecology
# 131971   450410                                  2          anesthesia
# 132845   451284                                  4          anesthesia
# 134423   452862                                  3          gynecology
# 134487   452926                                  4          gynecology
# 136965   455404                                  2          anesthesia
#
#        Ward_Type  Bed Grade  patientid  City_Code_Patient Type of Admission  \
# 888            S        3.0      27217                NaN            Trauma
# 3709           Q        3.0     124687                NaN         Emergency
# 8075           Q        2.0      45573                NaN            Trauma
# 8336           Q        3.0      99406                NaN         Emergency
# 8807           R        2.0      24857                NaN         Emergency
# 9373           Q        4.0      72315                NaN            Trauma
# 10420          Q        3.0        426                NaN         Emergency
# 10421          R        3.0        426                NaN         Emergency
# 11705          R        2.0     108144                NaN         Emergency
# 13886          S        2.0     113970                NaN         Emergency
# 13888          P        2.0     113970                NaN         Emergency
# 13969          S        3.0       6470                NaN         Emergency
# 14515          R        4.0      70712                NaN            Trauma
# 14517          Q        4.0      70712                NaN         Emergency
# 14756          Q        2.0      89359                NaN            Trauma
# 14757          R        3.0      89359                NaN            Trauma
# 14758          R        2.0      89359                NaN            Trauma
# 14983          R        2.0      62328                NaN            Trauma
# 15175          R        2.0       4565                NaN         Emergency
# 16709          Q        2.0      86382                NaN         Emergency
# 16710          S        3.0      86382                NaN         Emergency
# 16712          R        4.0      86382                NaN            Trauma
# 16838          P        2.0      34907                NaN         Emergency
# 17353          Q        3.0     127307                NaN         Emergency
# 17354          Q        4.0     127307                NaN            Trauma
# 17991          R        2.0        179                NaN         Emergency
# 17995          Q        2.0        179                NaN            Urgent
# 19566          Q        1.0      95185                NaN            Trauma
# 21539          Q        4.0      88817                NaN            Trauma
# 21544          R        3.0      88817                NaN            Trauma
# ...          ...        ...        ...                ...               ...
# 118161         Q        4.0     123422                NaN            Trauma
# 118163         P        2.0     123422                NaN            Trauma
# 118166         S        4.0     123422                NaN            Trauma
# 118630         S        2.0     100352                NaN         Emergency
# 120477         P        3.0      37156                NaN            Trauma
# 120741         R        2.0      78137                NaN            Urgent
# 121567         Q        3.0      36275                NaN            Urgent
# 121574         R        3.0      36275                NaN            Urgent
# 121575         Q        2.0      36275                NaN            Urgent
# 121770         Q        3.0       7658                NaN         Emergency
# 121855         R        2.0     108460                NaN         Emergency
# 123553         R        4.0      70468                NaN            Urgent
# 123575         Q        3.0      25943                NaN         Emergency
# 123814         R        2.0     131509                NaN            Urgent
# 123825         R        3.0     129584                NaN         Emergency
# 123835         Q        3.0      75368                NaN         Emergency
# 124709         Q        4.0      89603                NaN            Trauma
# 125127         R        2.0      63848                NaN         Emergency
# 125427         R        4.0      47340                NaN         Emergency
# 127266         R        4.0      40398                NaN            Trauma
# 128370         S        2.0     100593                NaN            Trauma
# 128710         Q        1.0      80259                NaN         Emergency
# 128711         R        1.0      80259                NaN            Trauma
# 128734         S        2.0      73898                NaN            Trauma
# 130684         R        4.0     113947                NaN         Emergency
# 131971         Q        4.0      73693                NaN         Emergency
# 132845         R        2.0      49657                NaN            Trauma
# 134423         Q        2.0      52407                NaN         Emergency
# 134487         Q        2.0      82837                NaN            Trauma
# 136965         Q        2.0      59861                NaN         Emergency
#
#        Severity of Illness     Age  Admission_Deposit
# 888                Extreme   51-60             3871.0
# 3709               Extreme   61-70             3992.0
# 8075              Moderate   31-40             4075.0
# 8336              Moderate   71-80             4594.0
# 8807                 Minor   71-80             7117.0
# 9373              Moderate   71-80             4961.0
# 10420             Moderate   21-30             3005.0
# 10421             Moderate   21-30             7780.0
# 11705                Minor   41-50             8766.0
# 13886                Minor   11-20             5504.0
# 13888                Minor   11-20             3246.0
# 13969             Moderate   41-50             5047.0
# 14515              Extreme   41-50             3873.0
# 14517              Extreme   41-50             3568.0
# 14756             Moderate   21-30             3786.0
# 14757             Moderate   21-30             4292.0
# 14758             Moderate   21-30             3981.0
# 14983             Moderate   71-80             7358.0
# 15175             Moderate   61-70             7823.0
# 16709              Extreme   51-60             7749.0
# 16710              Extreme   51-60             3471.0
# 16712              Extreme   51-60             4789.0
# 16838             Moderate   41-50             6401.0
# 17353                Minor   41-50             4713.0
# 17354                Minor   41-50             6388.0
# 17991             Moderate   41-50             4909.0
# 17995             Moderate   41-50             4536.0
# 19566              Extreme   41-50             5018.0
# 21539             Moderate   51-60             5040.0
# 21544             Moderate   51-60             7388.0
# ...                    ...     ...                ...
# 118161            Moderate   51-60             2994.0
# 118163            Moderate   51-60             3881.0
# 118166            Moderate   51-60             3117.0
# 118630             Extreme   21-30             3907.0
# 120477            Moderate   31-40             3836.0
# 120741            Moderate   11-20             6003.0
# 121567            Moderate   41-50             5552.0
# 121574            Moderate   41-50             4448.0
# 121575            Moderate   41-50             5357.0
# 121770            Moderate   11-20             6276.0
# 121855               Minor   41-50             3771.0
# 123553            Moderate   31-40             4471.0
# 123575               Minor   41-50             4460.0
# 123814               Minor   31-40             4814.0
# 123825               Minor   41-50             4983.0
# 123835            Moderate   31-40             3147.0
# 124709            Moderate   31-40             4801.0
# 125127               Minor   31-40             4778.0
# 125427            Moderate   41-50             3801.0
# 127266               Minor   61-70             4120.0
# 128370            Moderate   41-50             4547.0
# 128710            Moderate   41-50             4018.0
# 128711            Moderate   41-50             4445.0
# 128734            Moderate   61-70             5721.0
# 130684            Moderate   31-40             4801.0
# 131971            Moderate   41-50             2865.0
# 132845            Moderate  91-100             4169.0
# 134423               Minor   51-60             3150.0
# 134487            Moderate   31-40             3395.0
# 136965               Minor   41-50             4739.0
#
# [203 rows x 11 columns]

# %%
sns.countplot(y="Department", data=df1, hue = 'Stay')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-fab1b0ca53d4> in <module>
# ----> 1 sns.countplot(y="Department", data=df1, hue = 'Stay')
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3551                           estimator, ci, n_boot, units,
#    3552                           orient, color, palette, saturation,
# -> 3553                           errcolor, errwidth, capsize, dodge)
#    3554
#    3555     plotter.value_label = "count"
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Stay'

# %%
sns.countplot(y="Department", data=df1[df1['Age']>'30'], hue = 'Age')

# %%
sns.countplot(y="Department", data=df1, hue = 'Bed Grade')

# %%
sns.countplot(y="Department", data=df1, hue = 'Type of Admission')

# %%
sns.countplot(y='Department', data=df1, hue='Severity of Illness')

# %%
df.shape
# Out:
# (137057, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137057 entries, 0 to 137056
# Data columns (total 17 columns):
# case_id                              137057 non-null int64
# Hospital_code                        137057 non-null int64
# Hospital_type_code                   137057 non-null object
# City_Code_Hospital                   137057 non-null int64
# Hospital_region_code                 137057 non-null object
# Available Extra Rooms in Hospital    137057 non-null int64
# Department                           137057 non-null object
# Ward_Type                            137057 non-null object
# Ward_Facility_Code                   137057 non-null object
# Bed Grade                            137022 non-null float64
# patientid                            137057 non-null int64
# City_Code_Patient                    134900 non-null float64
# Type of Admission                    137057 non-null object
# Severity of Illness                  137057 non-null object
# Visitors with Patient                137057 non-null int64
# Age                                  137057 non-null object
# Admission_Deposit                    137057 non-null float64
# dtypes: float64(3), int64(6), object(8)
# memory usage: 17.8+ MB

# %%
df['Department'].value_counts()
# Out:
# gynecology            107202
# anesthesia             12709
# radiotherapy           12517
# TB & Chest disease      4165
# surgery                  464
# Name: Department, dtype: int64

# %%
df['Severity of Illness'].value_counts()
# Out:
# Moderate    75722
# Minor       36863
# Extreme     24472
# Name: Severity of Illness, dtype: int64

# %%
df['Hospital_region_code'].value_counts()
# Out:
# X    57513
# Y    52279
# Z    27265
# Name: Hospital_region_code, dtype: int64

# %%
df['Type of Admission'].value_counts()
# Out:
# Trauma       65411
# Emergency    50687
# Urgent       20959
# Name: Type of Admission, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# 41-50     27746
# 31-40     26781
# 51-60     20992
# 21-30     17717
# 71-80     14945
# 61-70     14932
# 11-20      7103
# 81-90      3350
# 0-10       2886
# 91-100      605
# Name: Age, dtype: int64

# %%
df['Hospital_type_code'].value_counts()
# Out:
# a    61305
# b    29938
# c    20219
# e    10658
# d     8659
# f     4549
# g     1729
# Name: Hospital_type_code, dtype: int64

# %%
df.groupby('Hospital_region_code')['Hospital_type_code'].value_counts()
# Out:
# Hospital_region_code  Hospital_type_code
# X                     a                     39420
#                       e                     10658
#                       b                      7435
# Y                     b                     22503
#                       a                     19689
#                       f                      4549
#                       d                      3809
#                       g                      1729
# Z                     c                     20219
#                       d                      4850
#                       a                      2196
# Name: Hospital_type_code, dtype: int64

# %%
df['City_Code_Patient'].value_counts()
# Out:
# 8.0     52814
# 2.0     16812
# 1.0     11395
# 7.0     10151
# 5.0      8899
# 4.0      6664
# 9.0      4897
# 15.0     3854
# 10.0     3635
# 6.0      2718
# 12.0     2477
# 3.0      1629
# 23.0     1622
# 14.0     1291
# 16.0      933
# 21.0      696
# 18.0      606
# 13.0      603
# 20.0      527
# 26.0      499
# 19.0      430
# 25.0      373
# 11.0      275
# 27.0      261
# 28.0      193
# 24.0      154
# 22.0      129
# 29.0       94
# 30.0       61
# 34.0       50
# 33.0       43
# 32.0       43
# 37.0       21
# 36.0       17
# 35.0       14
# 38.0       12
# 31.0        8
# Name: City_Code_Patient, dtype: int64

# %%
df['patientid'].value_counts()
# Out:
# 114456    37
# 85812     28
# 55666     26
# 37144     26
# 54096     25
# 51543     24
# 19476     22
# 84496     22
# 33561     21
# 28788     21
# 89917     21
# 40931     20
# 14899     20
# 75079     20
# 57774     19
# 16638     19
# 51006     19
# 71954     19
# 58492     19
# 24123     18
# 37380     18
# 131040    18
# 31884     18
# 24813     18
# 100069    18
# 67551     17
# 44633     17
# 58548     17
# 33029     17
# 92416     17
#           ..
# 116049     1
# 122194     1
# 63926      1
# 59828      1
# 76876      1
# 19360      1
# 121554     1
# 5035       1
# 32038      1
# 111903     1
# 113950     1
# 109852     1
# 123605     1
# 113374     1
# 81166      1
# 25317      1
# 29415      1
# 10988      1
# 58549      1
# 9389       1
# 29863      1
# 31910      1
# 99481      1
# 76940      1
# 66697      1
# 87171      1
# 103451     1
# 80910      1
# 23522      1
# 53811      1
# Name: patientid, Length: 39607, dtype: int64

# %%
df['Hospital_code'].value_counts()
# Out:
# 26    14447
# 23    11654
# 19     8817
# 6      8796
# 11     7499
# 28     7435
# 14     7387
# 27     5999
# 12     4873
# 9      4850
# 29     4847
# 32     4549
# 25     4212
# 10     4103
# 15     4069
# 21     3634
# 24     3475
# 3      3161
# 17     2343
# 30     2213
# 1      2211
# 13     2196
# 5      2187
# 2      2175
# 31     1773
# 22     1729
# 8      1621
# 18     1598
# 16     1573
# 7       565
# 20      557
# 4       509
# Name: Hospital_code, dtype: int64

# %%
df.groupby('Hospital_type_code')['Hospital_code'].value_counts()
# Out:
# Hospital_type_code  Hospital_code
# a                   23               11654
#                     19                8817
#                     6                 8796
#                     14                7387
#                     27                5999
#                     12                4873
#                     29                4847
#                     24                3475
#                     13                2196
#                     5                 2187
#                     7                  565
#                     4                  509
# b                   26               14447
#                     11                7499
#                     28                7435
#                     20                 557
# c                   15                4069
#                     21                3634
#                     3                 3161
#                     30                2213
#                     2                 2175
#                     31                1773
#                     8                 1621
#                     16                1573
# d                   9                 4850
#                     1                 2211
#                     18                1598
# e                   25                4212
#                     10                4103
#                     17                2343
# f                   32                4549
# g                   22                1729
# Name: Hospital_code, dtype: int64

# %%
df.isna().sum()
# Out:
# case_id                                 0
# Hospital_code                           0
# Hospital_type_code                      0
# City_Code_Hospital                      0
# Hospital_region_code                    0
# Available Extra Rooms in Hospital       0
# Department                              0
# Ward_Type                               0
# Ward_Facility_Code                      0
# Bed Grade                              35
# patientid                               0
# City_Code_Patient                    2157
# Type of Admission                       0
# Severity of Illness                     0
# Visitors with Patient                   0
# Age                                     0
# Admission_Deposit                       0
# dtype: int64

# %%
df[df['Bed Grade'].isnull()]
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 1399     319838              6                  a                   6
# 1604     320043              6                  a                   6
# 3579     322018              6                  a                   6
# 24465    342904              6                  a                   6
# 25733    344172              6                  a                   6
# 28311    346750              6                  a                   6
# 33385    351824              7                  a                   4
# 37913    356352              6                  a                   6
# 45127    363566              6                  a                   6
# 46964    365403              6                  a                   6
# 50642    369081              6                  a                   6
# 50772    369211              6                  a                   6
# 50869    369308              6                  a                   6
# 52650    371089              6                  a                   6
# 61210    379649              6                  a                   6
# 63631    382070              6                  a                   6
# 65597    384036              6                  a                   6
# 66705    385144              6                  a                   6
# 70707    389146              6                  a                   6
# 74332    392771              6                  a                   6
# 76428    394867              6                  a                   6
# 77135    395574              6                  a                   6
# 91395    409834              6                  a                   6
# 92872    411311              6                  a                   6
# 93786    412225              6                  a                   6
# 94385    412824              6                  a                   6
# 99562    418001              6                  a                   6
# 99693    418132              6                  a                   6
# 99793    418232              6                  a                   6
# 100041   418480              6                  a                   6
# 100517   418956              6                  a                   6
# 100698   419137              6                  a                   6
# 100704   419143              6                  a                   6
# 101594   420033              6                  a                   6
# 101839   420278              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital  \
# 1399                      X                                  3
# 1604                      X                                  2
# 3579                      X                                  2
# 24465                     X                                  3
# 25733                     X                                  2
# 28311                     X                                  4
# 33385                     X                                  3
# 37913                     X                                  2
# 45127                     X                                  3
# 46964                     X                                  5
# 50642                     X                                  3
# 50772                     X                                  4
# 50869                     X                                  4
# 52650                     X                                  2
# 61210                     X                                  4
# 63631                     X                                  5
# 65597                     X                                  4
# 66705                     X                                  3
# 70707                     X                                  3
# 74332                     X                                  3
# 76428                     X                                  4
# 77135                     X                                  4
# 91395                     X                                  4
# 92872                     X                                  2
# 93786                     X                                  3
# 94385                     X                                  4
# 99562                     X                                  2
# 99693                     X                                  3
# 99793                     X                                  3
# 100041                    X                                  4
# 100517                    X                                  2
# 100698                    X                                  2
# 100704                    X                                  2
# 101594                    X                                  3
# 101839                    X                                  3
#
#                 Department Ward_Type Ward_Facility_Code  Bed Grade  patientid  \
# 1399            gynecology         R                  F        NaN     105262
# 1604            gynecology         R                  F        NaN     104709
# 3579            gynecology         R                  F        NaN     113895
# 24465           gynecology         R                  F        NaN      90732
# 25733           gynecology         R                  F        NaN      62134
# 28311           gynecology         R                  F        NaN      24838
# 33385           gynecology         R                  F        NaN      87796
# 37913         radiotherapy         Q                  F        NaN      32430
# 45127         radiotherapy         R                  F        NaN      31605
# 46964           gynecology         R                  F        NaN     124059
# 50642           gynecology         R                  F        NaN      20031
# 50772           gynecology         Q                  F        NaN      50392
# 50869           gynecology         R                  F        NaN      73222
# 52650           gynecology         Q                  F        NaN      67836
# 61210           gynecology         R                  F        NaN     107362
# 63631           gynecology         Q                  F        NaN      26896
# 65597           gynecology         Q                  F        NaN     108088
# 66705         radiotherapy         R                  F        NaN      47789
# 70707           gynecology         R                  F        NaN     105256
# 74332   TB & Chest disease         R                  F        NaN      62906
# 76428           gynecology         Q                  F        NaN     120758
# 77135           gynecology         R                  F        NaN      67970
# 91395           gynecology         Q                  F        NaN      96430
# 92872           gynecology         R                  F        NaN      38814
# 93786           gynecology         R                  F        NaN      11763
# 94385           gynecology         Q                  F        NaN      46813
# 99562           gynecology         Q                  F        NaN      84213
# 99693           gynecology         R                  F        NaN     103004
# 99793           gynecology         R                  F        NaN     131552
# 100041          gynecology         Q                  F        NaN      49545
# 100517          gynecology         R                  F        NaN      52799
# 100698          gynecology         R                  F        NaN      62257
# 100704          gynecology         R                  F        NaN      39394
# 101594          gynecology         R                  F        NaN      57420
# 101839          gynecology         R                  F        NaN      51821
#
#         City_Code_Patient Type of Admission Severity of Illness  \
# 1399                  2.0            Trauma             Extreme
# 1604                 15.0            Trauma             Extreme
# 3579                  1.0            Trauma            Moderate
# 24465                 8.0            Trauma             Extreme
# 25733                 5.0            Trauma             Extreme
# 28311                 2.0            Trauma             Extreme
# 33385                 2.0         Emergency             Extreme
# 37913                 5.0            Trauma             Extreme
# 45127                 2.0            Trauma            Moderate
# 46964                15.0         Emergency            Moderate
# 50642                 2.0            Trauma            Moderate
# 50772                 8.0         Emergency            Moderate
# 50869                 2.0            Trauma            Moderate
# 52650                 8.0            Trauma             Extreme
# 61210                 2.0         Emergency            Moderate
# 63631                 2.0            Trauma             Extreme
# 65597                 8.0            Trauma             Extreme
# 66705                 2.0         Emergency            Moderate
# 70707                 8.0            Trauma             Extreme
# 74332                 8.0         Emergency            Moderate
# 76428                 8.0         Emergency            Moderate
# 77135                 8.0         Emergency            Moderate
# 91395                 8.0            Trauma            Moderate
# 92872                 7.0            Trauma             Extreme
# 93786                 7.0            Trauma            Moderate
# 94385                 2.0            Trauma             Extreme
# 99562                 1.0         Emergency            Moderate
# 99693                 8.0         Emergency            Moderate
# 99793                 5.0            Trauma            Moderate
# 100041                8.0         Emergency            Moderate
# 100517                7.0         Emergency            Moderate
# 100698                1.0            Trauma            Moderate
# 100704                2.0         Emergency            Moderate
# 101594                2.0            Trauma            Moderate
# 101839                7.0         Emergency            Moderate
#
#         Visitors with Patient    Age  Admission_Deposit
# 1399                        3  41-50             5051.0
# 1604                        2  71-80             5401.0
# 3579                        3  61-70             4936.0
# 24465                       6  41-50             4057.0
# 25733                       2  71-80             4662.0
# 28311                       2  31-40             3210.0
# 33385                       6  41-50             4702.0
# 37913                       2  71-80             6599.0
# 45127                       2  21-30             4378.0
# 46964                       2  31-40             4088.0
# 50642                       3  21-30             4380.0
# 50772                       4  51-60             3977.0
# 50869                       2  21-30             4471.0
# 52650                       2  41-50             5360.0
# 61210                       3  51-60             4357.0
# 63631                       4  41-50             3605.0
# 65597                       4  41-50             5390.0
# 66705                       5  51-60             3580.0
# 70707                       2  41-50             5407.0
# 74332                       3  31-40             5015.0
# 76428                       4  61-70             3170.0
# 77135                       6  21-30             3483.0
# 91395                       4  31-40             3939.0
# 92872                       2  41-50             5884.0
# 93786                       3  51-60             4321.0
# 94385                       3  41-50             3695.0
# 99562                       2  61-70             4492.0
# 99693                       3  51-60             4384.0
# 99793                       6  41-50             3741.0
# 100041                      8  51-60             7019.0
# 100517                      2  41-50             4613.0
# 100698                      3  61-70             5191.0
# 100704                      2  41-50             3451.0
# 101594                      2  51-60             4967.0
# 101839                      2  41-50             5247.0

# %%
df[df['Bed Grade'].isnull()]['Hospital_region_code'].value_counts()
# Out:
# X    35
# Name: Hospital_region_code, dtype: int64

# %%
df[df['Bed Grade'].isnull()]['City_Code_Hospital'].value_counts()
# Out:
# 6    34
# 4     1
# Name: City_Code_Hospital, dtype: int64

# %%
df[df['Bed Grade'].isnull()]['Hospital_type_code'].value_counts()
# Out:
# a    35
# Name: Hospital_type_code, dtype: int64

# %%
df[df['Bed Grade'].isnull()]['Hospital_code'].value_counts()
# Out:
# 6    34
# 7     1
# Name: Hospital_code, dtype: int64

# %%
df[df['Bed Grade'].isnull()]['Department'].value_counts()
# Out:
# gynecology            31
# radiotherapy           3
# TB & Chest disease     1
# Name: Department, dtype: int64

# %%
df[df['Hospital_type_code']=='a']['Bed Grade'].value_counts()
# Out:
# 2.0    23560
# 3.0    21519
# 4.0    10410
# 1.0     5781
# Name: Bed Grade, dtype: int64

# %%
df[df['Hospital_region_code']=='X']['Bed Grade'].value_counts()
# Out:
# 3.0    22036
# 2.0    20087
# 4.0    11542
# 1.0     3813
# Name: Bed Grade, dtype: int64

# %%
df
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        318439             21                  c                   3
# 1        318440             29                  a                   4
# 2        318441             26                  b                   2
# 3        318442              6                  a                   6
# 4        318443             28                  b                  11
# 5        318444             23                  a                   6
# 6        318445             26                  b                   2
# 7        318446             25                  e                   1
# 8        318447             23                  a                   6
# 9        318448             23                  a                   6
# 10       318449             10                  e                   1
# 11       318450              4                  a                   4
# 12       318451             16                  c                   3
# 13       318452             28                  b                  11
# 14       318453             19                  a                   7
# 15       318454             26                  b                   2
# 16       318455             19                  a                   7
# 17       318456             26                  b                   2
# 18       318457             23                  a                   6
# 19       318458             25                  e                   1
# 20       318459             32                  f                   9
# 21       318460             26                  b                   2
# 22       318461             11                  b                   2
# 23       318462              6                  a                   6
# 24       318463              1                  d                  10
# 25       318464              6                  a                   6
# 26       318465             15                  c                   5
# 27       318466             15                  c                   5
# 28       318467             23                  a                   6
# 29       318468              6                  a                   6
# ...         ...            ...                ...                 ...
# 137027   455466             32                  f                   9
# 137028   455467             19                  a                   7
# 137029   455468             15                  c                   5
# 137030   455469              9                  d                   5
# 137031   455470             25                  e                   1
# 137032   455471             27                  a                   7
# 137033   455472             12                  a                   9
# 137034   455473             17                  e                   1
# 137035   455474             16                  c                   3
# 137036   455475             23                  a                   6
# 137037   455476             23                  a                   6
# 137038   455477              6                  a                   6
# 137039   455478             19                  a                   7
# 137040   455479             24                  a                   1
# 137041   455480             19                  a                   7
# 137042   455481             11                  b                   2
# 137043   455482             15                  c                   5
# 137044   455483             15                  c                   5
# 137045   455484             19                  a                   7
# 137046   455485             14                  a                   1
# 137047   455486              9                  d                   5
# 137048   455487             13                  a                   5
# 137049   455488             12                  a                   9
# 137050   455489             13                  a                   5
# 137051   455490             15                  c                   5
# 137052   455491             11                  b                   2
# 137053   455492             25                  e                   1
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital  \
# 0                         Z                                  3
# 1                         X                                  2
# 2                         Y                                  3
# 3                         X                                  3
# 4                         X                                  2
# 5                         X                                  3
# 6                         Y                                  2
# 7                         X                                  4
# 8                         X                                  4
# 9                         X                                  3
# 10                        X                                  4
# 11                        X                                  3
# 12                        Z                                  4
# 13                        X                                  3
# 14                        Y                                  1
# 15                        Y                                  5
# 16                        Y                                  2
# 17                        Y                                  3
# 18                        X                                  4
# 19                        X                                  2
# 20                        Y                                  2
# 21                        Y                                  2
# 22                        Y                                  2
# 23                        X                                  2
# 24                        Y                                  3
# 25                        X                                  2
# 26                        Z                                  4
# 27                        Z                                  6
# 28                        X                                  4
# 29                        X                                  3
# ...                     ...                                ...
# 137027                    Y                                  3
# 137028                    Y                                  3
# 137029                    Z                                  2
# 137030                    Z                                  3
# 137031                    X                                  4
# 137032                    Y                                  6
# 137033                    Y                                  4
# 137034                    X                                  2
# 137035                    Z                                  2
# 137036                    X                                  4
# 137037                    X                                  4
# 137038                    X                                  4
# 137039                    Y                                  5
# 137040                    X                                  2
# 137041                    Y                                  2
# 137042                    Y                                  3
# 137043                    Z                                  5
# 137044                    Z                                  2
# 137045                    Y                                  3
# 137046                    X                                  2
# 137047                    Z                                  2
# 137048                    Z                                  2
# 137049                    Y                                  6
# 137050                    Z                                  3
# 137051                    Z                                  2
# 137052                    Y                                  4
# 137053                    X                                  2
# 137054                    Z                                  2
# 137055                    X                                  2
# 137056                    X                                  3
#
#                 Department Ward_Type Ward_Facility_Code  Bed Grade  patientid  \
# 0               gynecology         S                  A        2.0      17006
# 1               gynecology         S                  F        2.0      17006
# 2               gynecology         Q                  D        4.0      17006
# 3               gynecology         Q                  F        2.0      17006
# 4               gynecology         R                  F        2.0      17006
# 5               gynecology         Q                  F        2.0      17006
# 6               gynecology         Q                  D        2.0      17006
# 7               gynecology         S                  E        3.0      95946
# 8               gynecology         Q                  F        3.0      95946
# 9               gynecology         Q                  F        4.0      95946
# 10              gynecology         Q                  E        2.0      95946
# 11              gynecology         R                  F        3.0      95946
# 12              gynecology         R                  A        3.0      95946
# 13              gynecology         R                  F        4.0      95946
# 14              gynecology         S                  C        2.0      40728
# 15              gynecology         S                  D        4.0      40728
# 16              gynecology         S                  C        4.0      40728
# 17              gynecology         P                  D        4.0      40728
# 18              anesthesia         Q                  F        2.0      40728
# 19              anesthesia         S                  E        2.0      40728
# 20              gynecology         S                  B        2.0      40728
# 21              gynecology         R                  D        3.0      40728
# 22              gynecology         S                  D        3.0      40728
# 23              anesthesia         R                  F        3.0     128946
# 24              gynecology         R                  B        2.0     128946
# 25              gynecology         R                  F        4.0     128946
# 26              gynecology         P                  F        3.0     128946
# 27              gynecology         P                  F        2.0     128946
# 28              anesthesia         Q                  F        4.0     128946
# 29              gynecology         Q                  F        3.0     128946
# ...                    ...       ...                ...        ...        ...
# 137027          gynecology         S                  B        2.0      15179
# 137028          gynecology         Q                  C        3.0      84978
# 137029        radiotherapy         R                  F        4.0      43022
# 137030          gynecology         R                  F        4.0      67792
# 137031          gynecology         R                  E        4.0      45954
# 137032          gynecology         Q                  C        4.0      40918
# 137033          gynecology         S                  B        2.0      90642
# 137034          anesthesia         R                  E        4.0      68012
# 137035          gynecology         S                  A        4.0       1617
# 137036          anesthesia         Q                  F        4.0     109822
# 137037          gynecology         R                  F        4.0     101360
# 137038          gynecology         R                  F        4.0     101360
# 137039          gynecology         Q                  C        2.0      41025
# 137040  TB & Chest disease         R                  E        4.0      75048
# 137041          gynecology         S                  C        2.0     124764
# 137042          gynecology         Q                  D        3.0      84400
# 137043          gynecology         Q                  F        4.0      93774
# 137044          gynecology         R                  F        4.0      14503
# 137045          gynecology         Q                  C        3.0      15705
# 137046          anesthesia         Q                  E        4.0      35621
# 137047          gynecology         S                  F        4.0      55235
# 137048          gynecology         R                  F        3.0      55235
# 137049          gynecology         Q                  B        2.0      99515
# 137050          gynecology         R                  F        3.0      22878
# 137051          gynecology         S                  F        4.0     118215
# 137052          anesthesia         Q                  D        3.0      41160
# 137053        radiotherapy         R                  E        4.0      30985
# 137054          anesthesia         R                  A        4.0      81811
# 137055          anesthesia         R                  E        4.0      57021
# 137056          gynecology         Q                  F        4.0     126729
#
#         City_Code_Patient Type of Admission Severity of Illness  \
# 0                     2.0         Emergency            Moderate
# 1                     2.0            Trauma            Moderate
# 2                     2.0         Emergency            Moderate
# 3                     2.0            Trauma            Moderate
# 4                     2.0            Trauma            Moderate
# 5                     2.0            Trauma            Moderate
# 6                     2.0            Trauma            Moderate
# 7                     NaN         Emergency            Moderate
# 8                     NaN            Trauma            Moderate
# 9                     NaN            Urgent            Moderate
# 10                    NaN            Trauma            Moderate
# 11                    NaN         Emergency            Moderate
# 12                    NaN            Trauma            Moderate
# 13                    NaN            Urgent            Moderate
# 14                    8.0         Emergency            Moderate
# 15                    8.0         Emergency            Moderate
# 16                    8.0         Emergency            Moderate
# 17                    8.0            Trauma            Moderate
# 18                    8.0         Emergency            Moderate
# 19                    8.0            Trauma            Moderate
# 20                    8.0            Urgent            Moderate
# 21                    8.0            Urgent            Moderate
# 22                    8.0            Urgent            Moderate
# 23                    7.0         Emergency            Moderate
# 24                    7.0            Trauma            Moderate
# 25                    7.0            Trauma            Moderate
# 26                    7.0            Trauma            Moderate
# 27                    7.0         Emergency            Moderate
# 28                    7.0            Urgent            Moderate
# 29                    7.0            Urgent            Moderate
# ...                   ...               ...                 ...
# 137027                8.0            Urgent            Moderate
# 137028                8.0         Emergency            Moderate
# 137029                7.0            Urgent               Minor
# 137030                5.0            Urgent            Moderate
# 137031               10.0            Trauma               Minor
# 137032                8.0            Trauma               Minor
# 137033                7.0            Urgent               Minor
# 137034               18.0            Urgent               Minor
# 137035                4.0         Emergency               Minor
# 137036                5.0            Trauma            Moderate
# 137037                2.0         Emergency               Minor
# 137038                2.0         Emergency               Minor
# 137039                8.0         Emergency            Moderate
# 137040               10.0            Trauma               Minor
# 137041                8.0         Emergency               Minor
# 137042               18.0            Urgent             Extreme
# 137043               21.0         Emergency            Moderate
# 137044                8.0            Trauma            Moderate
# 137045                8.0         Emergency               Minor
# 137046               10.0            Urgent               Minor
# 137047                4.0         Emergency            Moderate
# 137048                4.0         Emergency            Moderate
# 137049                7.0         Emergency            Moderate
# 137050               21.0         Emergency            Moderate
# 137051                6.0            Urgent               Minor
# 137052                3.0         Emergency               Minor
# 137053                7.0         Emergency            Moderate
# 137054               12.0            Urgent               Minor
# 137055               10.0            Trauma               Minor
# 137056                3.0            Trauma             Extreme
#
#         Visitors with Patient    Age  Admission_Deposit
# 0                           2  71-80             3095.0
# 1                           4  71-80             4018.0
# 2                           3  71-80             4492.0
# 3                           3  71-80             4173.0
# 4                           4  71-80             4161.0
# 5                           2  71-80             4659.0
# 6                           2  71-80             4167.0
# 7                           2  31-40             4396.0
# 8                           2  31-40             4088.0
# 9                           2  31-40             3925.0
# 10                          2  31-40             4241.0
# 11                          6  31-40             3468.0
# 12                          3  31-40             4322.0
# 13                          2  31-40             4315.0
# 14                          4  51-60             3288.0
# 15                          4  51-60             6818.0
# 16                          2  51-60             3410.0
# 17                          6  51-60             4782.0
# 18                          4  51-60             5357.0
# 19                          2  51-60             6984.0
# 20                          2  51-60             5716.0
# 21                          6  51-60             3410.0
# 22                          2  51-60             5069.0
# 23                          4  51-60             4596.0
# 24                          6  51-60             3933.0
# 25                          3  51-60             4884.0
# 26                          4  51-60             5138.0
# 27                          6  51-60             3753.0
# 28                          2  51-60             5397.0
# 29                          5  51-60             3143.0
# ...                       ...    ...                ...
# 137027                      2  41-50             4397.0
# 137028                      5  51-60             3906.0
# 137029                      2  11-20             8316.0
# 137030                      2  11-20             3815.0
# 137031                      5  61-70             4050.0
# 137032                      3  21-30             3017.0
# 137033                      4  71-80             4365.0
# 137034                      2  61-70             4587.0
# 137035                      3  31-40             8933.0
# 137036                      4  41-50             5760.0
# 137037                      6   0-10             3020.0
# 137038                      6   0-10             3858.0
# 137039                      4  71-80             3862.0
# 137040                      3  41-50             4749.0
# 137041                      4  51-60             2804.0
# 137042                      3  51-60             5577.0
# 137043                      4  71-80             5675.0
# 137044                      2  51-60             5416.0
# 137045                      3  51-60             3641.0
# 137046                      2   0-10             4800.0
# 137047                      3  31-40             4418.0
# 137048                      2  31-40             3816.0
# 137049                      4  61-70             4406.0
# 137050                      3  21-30             4573.0
# 137051                      2  21-30             5241.0
# 137052                      4  41-50             6313.0
# 137053                      2   0-10             3510.0
# 137054                      2   0-10             7190.0
# 137055                      2  41-50             5435.0
# 137056                      5  51-60             4702.0
#
# [137057 rows x 17 columns]

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
dtypes = {"case_id":"uint32","Hospital_code":'uint8','City_Code_Hospital':"uint8","Available Extra Rooms in Hospital":"uint8","Visitors with Patient":"uint8","Admission_Deposit":"float32"}
train = pd.read_csv(r'C:\Users\KIIT\Downloads\Test_ND2Q3bm\test.csv',dtype=dtypes)
test  = pd.read_csv(r'C:\Users\KIIT\Downloads\Test_ND2Q3bm\test.csv',dtype=dtypes)

# %%
hospitals_visited_count_train = train.groupby('patientid')['Hospital_code'].nunique().to_dict()
train['hospitals_visited_by_patient'] = train['patientid'].map(hospitals_visited_count_train)
hospitals_visited_count_test = test.groupby('patientid')['Hospital_code'].nunique().to_dict()
test['hospitals_visited_by_patient'] = test['patientid'].map(hospitals_visited_count_test)


patient_admitted_count_train = train['patientid'].value_counts().to_dict()
train['patient_count'] = train['patientid'].map(patient_admitted_count_train)
patient_admitted_count_test = test['patientid'].value_counts().to_dict()
test['patient_count'] = test['patientid'].map(patient_admitted_count_test)


no_departments_visited_by_a_patient_train = train.groupby('patientid')['Department'].nunique().to_dict()
train['departments_visited'] = train['patientid'].map(no_departments_visited_by_a_patient_train)
no_departments_visited_by_a_patient_test = test.groupby('patientid')['Department'].nunique().to_dict()
test['departments_visited'] = test['patientid'].map(no_departments_visited_by_a_patient_test)


types_of_hospitals_visited_by_a_patient_train = train.groupby('patientid')['Hospital_type'].nunique().to_dict()
train['hospital_types_visited'] = train['patientid'].map(types_of_hospitals_visited_by_a_patient_train)
types_of_hospitals_visited_by_a_patient_test = test.groupby('patientid')['Hospital_type'].nunique().to_dict()
test['hospital_types_visited'] = test['patientid'].map(types_of_hospitals_visited_by_a_patient_test)


hospital_regions_visited_by_a_patient_train = train.groupby('patientid')['Hospital_region'].nunique().to_dict()
train['hospital_regions_visited'] = train['patientid'].map(hospital_regions_visited_by_a_patient_train)
hospital_regions_visited_by_a_patient_test = test.groupby('patientid')['Hospital_region'].nunique().to_dict()
test['hospital_regions_visited'] = test['patientid'].map(hospital_regions_visited_by_a_patient_test)


admission_types_train = train.groupby('patientid')['Admission_Type'].nunique().to_dict()
train['no_of_admission_types'] = train['patientid'].map(admission_types_train)
admission_types_test = test.groupby('patientid')['Admission_Type'].nunique().to_dict()
test['no_of_admission_types'] = test['patientid'].map(admission_types_test)


city_codes_visited_by_a_patient_train = train.groupby('patientid')['City_Code_Hospital'].nunique().to_dict()
train['city_codes_visited'] = train['patientid'].map(city_codes_visited_by_a_patient_train)
city_codes_visited_by_a_patient_test = test.groupby('patientid')['City_Code_Hospital'].nunique().to_dict()
test['city_codes_visited'] = test['patientid'].map(city_codes_visited_by_a_patient_test)


# creating an indicator variable to indicate if there is a change in the department admitted to for a patient
def change_in_department(x):
    if x > 1:
        return True
    else:
        return False
train['Change_In_Department'] = train['departments_visited'].apply(change_in_department)
test['Change_In_Department'] = test['departments_visited'].apply(change_in_department)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-7b0e48bccb07> in <module>
#      17
#      18
# ---> 19 types_of_hospitals_visited_by_a_patient_train = train.groupby('patientid')['Hospital_type'].nunique().to_dict()
#      20 train['hospital_types_visited'] = train['patientid'].map(types_of_hospitals_visited_by_a_patient_train)
#      21 types_of_hospitals_visited_by_a_patient_test = test.groupby('patientid')['Hospital_type'].nunique().to_dict()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     273         else:
#     274             if key not in self.obj:
# --> 275                 raise KeyError("Column not found: {key}".format(key=key))
#     276             return self._gotitem(key, ndim=1)
#     277
#
# KeyError: 'Column not found: Hospital_type'

# %%
agg_func = {
    'Deposit': ['mean','std','sum','median']    
}
agg_func = train.groupby('Hospital_code').agg(agg_func)
agg_func.columns = [ 'Hospital_code_' + ('_'.join(col).strip()) for col in agg_func.columns.values]
agg_func.reset_index(inplace=True)
train = train.merge(agg_func, on=['Hospital_code'], how='left')


agg_func = {
    'Deposit': ['mean','std','sum','median']    
}
agg_func = test.groupby('Hospital_code').agg(agg_func)
agg_func.columns = [ 'Hospital_code_' + ('_'.join(col).strip()) for col in agg_func.columns.values]
agg_func.reset_index(inplace=True)
test = test.merge(agg_func, on=['Hospital_code'], how='left')


unique_patients_by_hospital_code_train = train.groupby('Hospital_code')['patientid'].nunique().to_dict()
train['unique_patients_by_hospital_code'] = train['Hospital_code'].map(unique_patients_by_hospital_code_train)
unique_patients_by_hospital_code_test = test.groupby('Hospital_code')['patientid'].nunique().to_dict()
test['unique_patients_by_hospital_code'] = test['Hospital_code'].map(unique_patients_by_hospital_code_test)

scaler = MinMaxScaler()
for df in [train,test]:
    df[['Visitors']] = scaler.fit_transform(df[['Visitors']])
    df[['unique_patients_by_hospital_code']] = scaler.fit_transform(df[['unique_patients_by_hospital_code']])
    df[['Hospital_code_Deposit_median']] = scaler.fit_transform(df[['Hospital_code_Deposit_median']])
    df[['Hospital_code_Deposit_mean']] = scaler.fit_transform(df[['Hospital_code_Deposit_mean']])
    df[['Hospital_code_Deposit_std']] = scaler.fit_transform(df[['Hospital_code_Deposit_std']])
    df[['Hospital_code_Deposit_sum']] = scaler.fit_transform(df[['Hospital_code_Deposit_sum']])

# %%
for df in [train,test]:
    df['Dep_Adm'] = df['Department']+"_"+df['Admission_Type']
    df['Dep_Sev'] = df['Department']+"_"+df['Severity']
    df['Adm_Sev'] = df['Admission_Type']+"_"+df['Severity']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Admission_Type'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-b5a59a763c6f> in <module>
#       1 for df in [train,test]:
# ----> 2     df['Dep_Adm'] = df['Department']+"_"+df['Admission_Type']
#       3     df['Dep_Sev'] = df['Department']+"_"+df['Severity']
#       4     df['Adm_Sev'] = df['Admission_Type']+"_"+df['Severity']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Admission_Type'

# %%
# Replacing the categories in the target variable.
train['Stay'].replace({"0-10":1,"11-20":2,"21-30":3,"31-40":4,"41-50":5,"51-60":6,"61-70":7,"71-80":8,"81-90":9,"91-100":10,"More than 100 Days":11},inplace=True)
train['Stay'] = train['Stay'].astype('uint8')

# %%
le = LabelEncoder()
cat_cols = ['Hospital_code','Hospital_type','City_Code_Hospital','Hospital_region','Extra_Rooms','Department','Ward',
            'Ward_Facility','Bed_Grade','City_Code_Patient','Admission_Type','Severity','Age','Dep_Adm','Dep_Sev','Adm_Sev']
for col in cat_cols:
    train[col] = le.fit_transform(train[col])
    test[col] = le.fit_transform(test[col])

X = train[[col for col in train.columns if col!="Stay"]]
y = train['Stay']

# %%
accuracy = []
final_preds = []
folds = StratifiedKFold(n_splits=5)
for train_index, test_index in folds.split(X,y):
    # creating training and validation datasets
    X_Train, X_Test = X.iloc[train_index],X.iloc[test_index]
    y_Train, y_Test = y.iloc[train_index],y.iloc[test_index]
    
    # building a classifier
    clf = lgb.LGBMClassifier(n_estimators=750,
                             learning_rate=0.1,
                             objective="multiclass",
                             boosting_type="gbdt",
                             subsample=0.9,
                             colsample_bytree=0.6,
                             num_class=11,
                             max_depth=12,
                             n_jobs=-1,
                             reg_alpha=2,
                             num_leaves=100)
    
    # fitting the classifier to the train set
    clf.fit(X_Train,
            y_Train,
            eval_set=[(X_Train,y_Train),(X_Test,y_Test)],
            early_stopping_rounds=50,
            verbose=50,
            categorical_feature = cat_cols)
    
    # predicting on the validation set
    preds = clf.predict(X_Test)
    score = accuracy_score(preds,y_Test)
    print ("Accuracy Score:",score)
    print ("------------------------------------------------")
    accuracy.append(score)
    
    # Predicting on the test set, final_preds will be an array of 5 sets of predictions, one for each fold
    pred = clf.predict(test,num_iteration=None)
    final_preds.append(pred)
    
print ("------------------------------------------")
print ("Mean Accuracy of 5 Folds:",np.mean(np.array(accuracy)))

# %%
df
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        318439             21                  c                   3
# 1        318440             29                  a                   4
# 2        318441             26                  b                   2
# 3        318442              6                  a                   6
# 4        318443             28                  b                  11
# 5        318444             23                  a                   6
# 6        318445             26                  b                   2
# 7        318446             25                  e                   1
# 8        318447             23                  a                   6
# 9        318448             23                  a                   6
# 10       318449             10                  e                   1
# 11       318450              4                  a                   4
# 12       318451             16                  c                   3
# 13       318452             28                  b                  11
# 14       318453             19                  a                   7
# 15       318454             26                  b                   2
# 16       318455             19                  a                   7
# 17       318456             26                  b                   2
# 18       318457             23                  a                   6
# 19       318458             25                  e                   1
# 20       318459             32                  f                   9
# 21       318460             26                  b                   2
# 22       318461             11                  b                   2
# 23       318462              6                  a                   6
# 24       318463              1                  d                  10
# 25       318464              6                  a                   6
# 26       318465             15                  c                   5
# 27       318466             15                  c                   5
# 28       318467             23                  a                   6
# 29       318468              6                  a                   6
# ...         ...            ...                ...                 ...
# 137027   455466             32                  f                   9
# 137028   455467             19                  a                   7
# 137029   455468             15                  c                   5
# 137030   455469              9                  d                   5
# 137031   455470             25                  e                   1
# 137032   455471             27                  a                   7
# 137033   455472             12                  a                   9
# 137034   455473             17                  e                   1
# 137035   455474             16                  c                   3
# 137036   455475             23                  a                   6
# 137037   455476             23                  a                   6
# 137038   455477              6                  a                   6
# 137039   455478             19                  a                   7
# 137040   455479             24                  a                   1
# 137041   455480             19                  a                   7
# 137042   455481             11                  b                   2
# 137043   455482             15                  c                   5
# 137044   455483             15                  c                   5
# 137045   455484             19                  a                   7
# 137046   455485             14                  a                   1
# 137047   455486              9                  d                   5
# 137048   455487             13                  a                   5
# 137049   455488             12                  a                   9
# 137050   455489             13                  a                   5
# 137051   455490             15                  c                   5
# 137052   455491             11                  b                   2
# 137053   455492             25                  e                   1
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital  \
# 0                         Z                                  3
# 1                         X                                  2
# 2                         Y                                  3
# 3                         X                                  3
# 4                         X                                  2
# 5                         X                                  3
# 6                         Y                                  2
# 7                         X                                  4
# 8                         X                                  4
# 9                         X                                  3
# 10                        X                                  4
# 11                        X                                  3
# 12                        Z                                  4
# 13                        X                                  3
# 14                        Y                                  1
# 15                        Y                                  5
# 16                        Y                                  2
# 17                        Y                                  3
# 18                        X                                  4
# 19                        X                                  2
# 20                        Y                                  2
# 21                        Y                                  2
# 22                        Y                                  2
# 23                        X                                  2
# 24                        Y                                  3
# 25                        X                                  2
# 26                        Z                                  4
# 27                        Z                                  6
# 28                        X                                  4
# 29                        X                                  3
# ...                     ...                                ...
# 137027                    Y                                  3
# 137028                    Y                                  3
# 137029                    Z                                  2
# 137030                    Z                                  3
# 137031                    X                                  4
# 137032                    Y                                  6
# 137033                    Y                                  4
# 137034                    X                                  2
# 137035                    Z                                  2
# 137036                    X                                  4
# 137037                    X                                  4
# 137038                    X                                  4
# 137039                    Y                                  5
# 137040                    X                                  2
# 137041                    Y                                  2
# 137042                    Y                                  3
# 137043                    Z                                  5
# 137044                    Z                                  2
# 137045                    Y                                  3
# 137046                    X                                  2
# 137047                    Z                                  2
# 137048                    Z                                  2
# 137049                    Y                                  6
# 137050                    Z                                  3
# 137051                    Z                                  2
# 137052                    Y                                  4
# 137053                    X                                  2
# 137054                    Z                                  2
# 137055                    X                                  2
# 137056                    X                                  3
#
#                 Department Ward_Type Ward_Facility_Code  Bed Grade  patientid  \
# 0               gynecology         S                  A        2.0      17006
# 1               gynecology         S                  F        2.0      17006
# 2               gynecology         Q                  D        4.0      17006
# 3               gynecology         Q                  F        2.0      17006
# 4               gynecology         R                  F        2.0      17006
# 5               gynecology         Q                  F        2.0      17006
# 6               gynecology         Q                  D        2.0      17006
# 7               gynecology         S                  E        3.0      95946
# 8               gynecology         Q                  F        3.0      95946
# 9               gynecology         Q                  F        4.0      95946
# 10              gynecology         Q                  E        2.0      95946
# 11              gynecology         R                  F        3.0      95946
# 12              gynecology         R                  A        3.0      95946
# 13              gynecology         R                  F        4.0      95946
# 14              gynecology         S                  C        2.0      40728
# 15              gynecology         S                  D        4.0      40728
# 16              gynecology         S                  C        4.0      40728
# 17              gynecology         P                  D        4.0      40728
# 18              anesthesia         Q                  F        2.0      40728
# 19              anesthesia         S                  E        2.0      40728
# 20              gynecology         S                  B        2.0      40728
# 21              gynecology         R                  D        3.0      40728
# 22              gynecology         S                  D        3.0      40728
# 23              anesthesia         R                  F        3.0     128946
# 24              gynecology         R                  B        2.0     128946
# 25              gynecology         R                  F        4.0     128946
# 26              gynecology         P                  F        3.0     128946
# 27              gynecology         P                  F        2.0     128946
# 28              anesthesia         Q                  F        4.0     128946
# 29              gynecology         Q                  F        3.0     128946
# ...                    ...       ...                ...        ...        ...
# 137027          gynecology         S                  B        2.0      15179
# 137028          gynecology         Q                  C        3.0      84978
# 137029        radiotherapy         R                  F        4.0      43022
# 137030          gynecology         R                  F        4.0      67792
# 137031          gynecology         R                  E        4.0      45954
# 137032          gynecology         Q                  C        4.0      40918
# 137033          gynecology         S                  B        2.0      90642
# 137034          anesthesia         R                  E        4.0      68012
# 137035          gynecology         S                  A        4.0       1617
# 137036          anesthesia         Q                  F        4.0     109822
# 137037          gynecology         R                  F        4.0     101360
# 137038          gynecology         R                  F        4.0     101360
# 137039          gynecology         Q                  C        2.0      41025
# 137040  TB & Chest disease         R                  E        4.0      75048
# 137041          gynecology         S                  C        2.0     124764
# 137042          gynecology         Q                  D        3.0      84400
# 137043          gynecology         Q                  F        4.0      93774
# 137044          gynecology         R                  F        4.0      14503
# 137045          gynecology         Q                  C        3.0      15705
# 137046          anesthesia         Q                  E        4.0      35621
# 137047          gynecology         S                  F        4.0      55235
# 137048          gynecology         R                  F        3.0      55235
# 137049          gynecology         Q                  B        2.0      99515
# 137050          gynecology         R                  F        3.0      22878
# 137051          gynecology         S                  F        4.0     118215
# 137052          anesthesia         Q                  D        3.0      41160
# 137053        radiotherapy         R                  E        4.0      30985
# 137054          anesthesia         R                  A        4.0      81811
# 137055          anesthesia         R                  E        4.0      57021
# 137056          gynecology         Q                  F        4.0     126729
#
#         City_Code_Patient Type of Admission Severity of Illness  \
# 0                     2.0         Emergency            Moderate
# 1                     2.0            Trauma            Moderate
# 2                     2.0         Emergency            Moderate
# 3                     2.0            Trauma            Moderate
# 4                     2.0            Trauma            Moderate
# 5                     2.0            Trauma            Moderate
# 6                     2.0            Trauma            Moderate
# 7                     NaN         Emergency            Moderate
# 8                     NaN            Trauma            Moderate
# 9                     NaN            Urgent            Moderate
# 10                    NaN            Trauma            Moderate
# 11                    NaN         Emergency            Moderate
# 12                    NaN            Trauma            Moderate
# 13                    NaN            Urgent            Moderate
# 14                    8.0         Emergency            Moderate
# 15                    8.0         Emergency            Moderate
# 16                    8.0         Emergency            Moderate
# 17                    8.0            Trauma            Moderate
# 18                    8.0         Emergency            Moderate
# 19                    8.0            Trauma            Moderate
# 20                    8.0            Urgent            Moderate
# 21                    8.0            Urgent            Moderate
# 22                    8.0            Urgent            Moderate
# 23                    7.0         Emergency            Moderate
# 24                    7.0            Trauma            Moderate
# 25                    7.0            Trauma            Moderate
# 26                    7.0            Trauma            Moderate
# 27                    7.0         Emergency            Moderate
# 28                    7.0            Urgent            Moderate
# 29                    7.0            Urgent            Moderate
# ...                   ...               ...                 ...
# 137027                8.0            Urgent            Moderate
# 137028                8.0         Emergency            Moderate
# 137029                7.0            Urgent               Minor
# 137030                5.0            Urgent            Moderate
# 137031               10.0            Trauma               Minor
# 137032                8.0            Trauma               Minor
# 137033                7.0            Urgent               Minor
# 137034               18.0            Urgent               Minor
# 137035                4.0         Emergency               Minor
# 137036                5.0            Trauma            Moderate
# 137037                2.0         Emergency               Minor
# 137038                2.0         Emergency               Minor
# 137039                8.0         Emergency            Moderate
# 137040               10.0            Trauma               Minor
# 137041                8.0         Emergency               Minor
# 137042               18.0            Urgent             Extreme
# 137043               21.0         Emergency            Moderate
# 137044                8.0            Trauma            Moderate
# 137045                8.0         Emergency               Minor
# 137046               10.0            Urgent               Minor
# 137047                4.0         Emergency            Moderate
# 137048                4.0         Emergency            Moderate
# 137049                7.0         Emergency            Moderate
# 137050               21.0         Emergency            Moderate
# 137051                6.0            Urgent               Minor
# 137052                3.0         Emergency               Minor
# 137053                7.0         Emergency            Moderate
# 137054               12.0            Urgent               Minor
# 137055               10.0            Trauma               Minor
# 137056                3.0            Trauma             Extreme
#
#         Visitors with Patient    Age  Admission_Deposit  \
# 0                           2  71-80             3095.0
# 1                           4  71-80             4018.0
# 2                           3  71-80             4492.0
# 3                           3  71-80             4173.0
# 4                           4  71-80             4161.0
# 5                           2  71-80             4659.0
# 6                           2  71-80             4167.0
# 7                           2  31-40             4396.0
# 8                           2  31-40             4088.0
# 9                           2  31-40             3925.0
# 10                          2  31-40             4241.0
# 11                          6  31-40             3468.0
# 12                          3  31-40             4322.0
# 13                          2  31-40             4315.0
# 14                          4  51-60             3288.0
# 15                          4  51-60             6818.0
# 16                          2  51-60             3410.0
# 17                          6  51-60             4782.0
# 18                          4  51-60             5357.0
# 19                          2  51-60             6984.0
# 20                          2  51-60             5716.0
# 21                          6  51-60             3410.0
# 22                          2  51-60             5069.0
# 23                          4  51-60             4596.0
# 24                          6  51-60             3933.0
# 25                          3  51-60             4884.0
# 26                          4  51-60             5138.0
# 27                          6  51-60             3753.0
# 28                          2  51-60             5397.0
# 29                          5  51-60             3143.0
# ...                       ...    ...                ...
# 137027                      2  41-50             4397.0
# 137028                      5  51-60             3906.0
# 137029                      2  11-20             8316.0
# 137030                      2  11-20             3815.0
# 137031                      5  61-70             4050.0
# 137032                      3  21-30             3017.0
# 137033                      4  71-80             4365.0
# 137034                      2  61-70             4587.0
# 137035                      3  31-40             8933.0
# 137036                      4  41-50             5760.0
# 137037                      6   0-10             3020.0
# 137038                      6   0-10             3858.0
# 137039                      4  71-80             3862.0
# 137040                      3  41-50             4749.0
# 137041                      4  51-60             2804.0
# 137042                      3  51-60             5577.0
# 137043                      4  71-80             5675.0
# 137044                      2  51-60             5416.0
# 137045                      3  51-60             3641.0
# 137046                      2   0-10             4800.0
# 137047                      3  31-40             4418.0
# 137048                      2  31-40             3816.0
# 137049                      4  61-70             4406.0
# 137050                      3  21-30             4573.0
# 137051                      2  21-30             5241.0
# 137052                      4  41-50             6313.0
# 137053                      2   0-10             3510.0
# 137054                      2   0-10             7190.0
# 137055                      2  41-50             5435.0
# 137056                      5  51-60             4702.0
#
#         hospitals_visited_by_patient  patient_count  departments_visited
# 0                                  6              7                    1
# 1                                  6              7                    1
# 2                                  6              7                    1
# 3                                  6              7                    1
# 4                                  6              7                    1
# 5                                  6              7                    1
# 6                                  6              7                    1
# 7                                  6              7                    1
# 8                                  6              7                    1
# 9                                  6              7                    1
# 10                                 6              7                    1
# 11                                 6              7                    1
# 12                                 6              7                    1
# 13                                 6              7                    1
# 14                                 6              9                    2
# 15                                 6              9                    2
# 16                                 6              9                    2
# 17                                 6              9                    2
# 18                                 6              9                    2
# 19                                 6              9                    2
# 20                                 6              9                    2
# 21                                 6              9                    2
# 22                                 6              9                    2
# 23                                 4              8                    3
# 24                                 4              8                    3
# 25                                 4              8                    3
# 26                                 4              8                    3
# 27                                 4              8                    3
# 28                                 4              8                    3
# 29                                 4              8                    3
# ...                              ...            ...                  ...
# 137027                             1              1                    1
# 137028                             1              1                    1
# 137029                             1              1                    1
# 137030                             1              1                    1
# 137031                             1              1                    1
# 137032                             1              1                    1
# 137033                             1              1                    1
# 137034                             1              1                    1
# 137035                             1              1                    1
# 137036                             1              1                    1
# 137037                             2              2                    1
# 137038                             2              2                    1
# 137039                             1              1                    1
# 137040                             1              1                    1
# 137041                             1              1                    1
# 137042                             1              1                    1
# 137043                             1              1                    1
# 137044                             1              1                    1
# 137045                             1              1                    1
# 137046                             1              1                    1
# 137047                             2              2                    1
# 137048                             2              2                    1
# 137049                             1              1                    1
# 137050                             1              1                    1
# 137051                             1              1                    1
# 137052                             1              1                    1
# 137053                             1              1                    1
# 137054                             1              1                    1
# 137055                             1              1                    1
# 137056                             1              1                    1
#
# [137057 rows x 20 columns]
